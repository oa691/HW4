# %%
from __future__ import division #with out this se runs into infinite!@#
import os
import sys
import numpy as np
import pylab as pl
import matplotlib.pyplot as pl
import math

# %pylab inline

#Null Hypothesis: The % of former prisoners employed after release
#is the same or lower for candidates who participated in the program
#as for the control group. significance level p=0.05
#Ho: Po-P1 >= 0 
#Ha: Po-P1 < 0
a = 0.05
P0 = 0.035 #Sample proportion from population 1
P1 = 0.701 #Sample proportion from population 2
P_0 = 3.5 * 0.01
P_1 = 70.1 * 0.01

if P0 - P1 >= 0:
    print ("The Null Hypothesis Holds")
else:
    print("We Must Asses the Statistical Significance since P0 - P1 !>= 0")
n_0 = 409 #The size of sample 1 
n_1 = 564 #The size of sample 2

#Gettiing Counts by Multiplying by the Sample Size
Nt_0 = P_0 * n_0
print ('The value of Nt_0is %5.3f.' %Nt_0 )
Nt_1 = P_1 * n_1
print ('The value of Nt_1 is %5.3f.' %Nt_1 )

#Assessing the Statistical Significance using Z-test
#Sample Proportion
#sp = (P0 * n_0 + P1 * n_1) / (n_1 + n_0)
#print (sp)

#Pooled sample proportion for se calculation
p = (Nt_0 + Nt_1) / (n_0 + n_1)
print ('The value of sample proprtion p is %5.3f.' %p )

#Standard Error of the sampling distribution, 
#for the mean of two samples
se = np.sqrt(p * (1 - p) * ((1 / n_0) + (1 / n_1)))
print ('The value of std error se is %8.6f.' %se )


#>>> print('The value of PI is approximately {}.'.format(math.pi))
#The value of PI is approximately 3.14159265359.
#>>> print('The value of PI is approximately {!r}.'.format(math.pi))
#The value of PI is approximately 3.141592653589793.

#Two proportion Test statistic - Z score: 
#Observation Vs Expected
#How many SD away from the population is this stat?
#2y for two tail

    
zscore = lambda P0, P1, se : (P0 - P1) / se
z_2y = zscore(P1, P0, se)
print ('The value of z_2y is less or greater than %5.3f.' %z_2y )


#if p < alpha : Ho is false

p_2y = 1 - 0.9998
print ('The value of p_2y is %7.5f.' %p_2y )

def report_result(p,a):
    print ('Is the p value ' + '{0:.3f} smaller than the critical value {1:.2f}?'.format(p,a))
    if p < a:
        print ("yes!")
        print ('The value of p_yes is %8.6f.' %p )
    else:
        print ("No")
        print ('The value of p_no is %5.3f.' %p )
    
    print ('the Null hypothesis is {}'.format(\
                            'rejected since p_yes<alpha' if p < a  else 'not rejected') )    

report_result(p_2y, a)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# We Must Asses the Statistical Significance since P0 - P1 !>= 0
# The value of Nt_0is 14.315.
# The value of Nt_1 is 395.364.
# The value of sample proprtion p is 0.421.
# The value of std error se is 0.032066.
# The value of z_2y is less or greater than 20.770.
# The value of p_2y is 0.00020.
# Is the p value 0.000 smaller than the critical value 0.05?
# yes!
# The value of p_yes is 0.000200.
# the Null hypothesis is rejected since p_yes<alpha

# %%
#what is the inmate was or was not conviected to a felony

from __future__ import division #with out this se runs into infinite!@#
import os
import sys
import numpy as np
import pylab as pl
import matplotlib.pyplot as pl
import math

# %pylab inline

#Null Hypothesis: The % of former prisoners convicted arrested or incarcerated after 1-3 year of release
#is the same or lower for former prisoners
#as for the control group. significance level p=0.05
#Ho: Po-P1 >= 0 
#Ha: Po-P1 < 0
#alpha = 0.05
a = 0.05
P0 = 0.706 #Sample proportion from population 1
P1 = 0.649 #Sample proportion from population 2
P_0 = 70.6 * 0.01
P_1 = 64.9 * 0.01

if P0 - P1 >= 0:
    print ("The Null Hypothesis Holds")
else:
    print("We Must Asses the Statistical Significance since P0 - P1 !>= 0")
n_0 = 409 #The size of sample 1 
n_1 = 568 #The size of sample 2

#Gettiing Counts by Multiplying by the Sample Size
Nt_0 = P_0 * n_0
print ('The value of Nt_0is %5.3f.' %Nt_0 )
Nt_1 = P_1 * n_1
print ('The value of Nt_1 is %5.3f.' %Nt_1 )


#Pooled sample proportion for se calculation
p = (Nt_0 + Nt_1) / (n_0 + n_1)
print ('The value of sample proprtion p is %5.3f.' %p )

#Standard Error of the sampling distribution, 
#for the mean of two samples
se = np.sqrt(p * (1 - p) * ((1 / n_0) + (1 / n_1)))
print ('The value of std error se is %8.6f.' %se )


#Two proportion Test statistic - Z score: 
#Observation Vs Expected
#How many SD away from the population is this stat?
#2y for two tail

    
zscore = lambda P0, P1, se : (P0 - P1) / se
z_2y = zscore(P1, P0, se)
print ('The value of z_2y is less or greater than %5.3f.' %z_2y )


#if p < alpha : Ho is false

p_2y = 1 - 0.9998
print ('The value of p_2y is %7.5f.' %p_2y )

def report_result(p,a):
    print ('Is the p value ' + '{0:.3f} smaller than the critical value {1:.2f}?'.format(p,a))
    if p < a:
        print ("yes!")
        print ('The value of p_yes is %8.6f.' %p )
    else:
        print ("No")
        print ('The value of p_no is %5.3f.' %p )
    
    print ('the Null hypothesis is {}'.format(\
                            'rejected since p_yes<alpha' if p < a  else 'not rejected') )    

report_result(p_2y, a)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The Null Hypothesis Holds
# The value of Nt_0is 288.754.
# The value of Nt_1 is 368.632.
# The value of sample proprtion p is 0.673.
# The value of std error se is 0.030426.
# The value of z_2y is less or greater than -1.873.
# The value of p_2y is 0.00020.
# Is the p value 0.000 smaller than the critical value 0.05?
# yes!
# The value of p_yes is 0.000200.
# the Null hypothesis is rejected since p_yes<alpha

# %%
#from evalChisq import evalChisq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-f716d3f93338> in <module>()
# ----> 1 from evalChisq import evalChisq
#
# ImportError: No module named 'evalChisq'

# %%
a = 0.05

def evalChisq(values):
    values = np.array(values)
    E = np.empty_like(values)
    for j in range(len(values[0])):
        for i in range(2):
            
            E[i][j] = ((values[i,:].sum() * values[:,j].sum()) / 
                        (values).sum())
    return ((values - E)**2 / E).sum()

sample_values = np.array([[0.701 * 564, 0.299 * 564], [0.0305 * 409, 0.965 * 409]]) 
#1 array observed frequency. 1-1 = 0 DOF                                                                                 
chi_values = evalChisq(sample_values)
print(values)

#Chi p value with alpha 0.05 and for DOF 1
#Table value for DOF 1 = 0.384
Ta = 0.384

#if chi_values < alpha_table : Ho is false

def report_result(values,Ta):
    print ('Is the  chi_values ' + '{0:.3f} smaller than the critical value {1:.2f} ?'.format(chi_values,Ta))
    if chi_values < Ta:
        print ("yes!")
        print ('The value of chi_values_yes is %8.6f.' %chi_values )
    else:
        print ("No")
        print ('The value of This value is %3.2f.' %chi_values )
    
    print ('the Null hypothesis is {}'.format(\
                            'rejected since chi_values_yes<alpha' if chi_values < Ta  else 'not rejected') )    

report_result(chi_values, Ta)


#432 larger then 3.84: calculated vs table p values so the hypothesis is accepted
#why am i mentioning 3.84? from the 2D table
#how does the chi square statistic that you derived compare?
#please state what that means in terms of your Null hypothesis in a markdown cell below!

#http://passel.unl.edu/Image/Namuth-CovertDeana956176274/chi-sqaure%20distribution%20table.PNG
#Above linked table gives the P value once we calculate DOF and determine the alpha we want to use. Here, it is 3.84 for 5% alpha

#ample_values = chisquare([[0.701 * 564, 0.299 * 564], [0.0305 * 409, 0.965 * 409]])
#print (chisquare(ample_values))
# Out:
# 436.223462575
# Is the  chi_values 436.223 smaller than the critical value 0.38 ?
# No
# The value of This value is 436.22.
# the Null hypothesis is not rejected
